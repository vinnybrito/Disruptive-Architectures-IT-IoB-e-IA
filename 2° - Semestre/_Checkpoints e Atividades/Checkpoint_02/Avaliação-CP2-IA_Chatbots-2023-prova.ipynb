# %% [markdown]
# # IA & Chatbots: Avaliação Aprendizado Supervisionado: Classificação
#
# FIAP - 03/05/2023
#
# Observações gerais:
#
# 1.	Para os gráficos pode-se usar as bibliotecas matplotlib ou seaborn.
#
# 2.	Liberada consulta aos apontamentos de aula.
#
# 3.	Escreve as respostas nas células correspondentes
#
# 4.	A prova deve ser feita em duplas.
#
# 5.	Deve ser entregue um notebook por turma. Salvar com nome: CP2_nome1_nome2.ipynb
#
# 6.	A prova deve ser carregada na tarefa do Teams.
#
# Turma -
#
# Insira os nomes e RM na célula abaixo:
#
# --------------------------

# %%
#  Nomes e RM:

# %% [markdown]
# ----------------------
# ## Exercício - Diagnóstico médico: Diabetes no povo Pima
#
# Esse dataset contém dados sobre incidência de diabetes em mulheres do Povo Pima (índios nativos norte americanos originários do atual Estado do Arizona). Contém 8 atributos biomédicos para 768 entradas anonimizadas, sendo 500 testados negativo para diabetes e 268 testados positivo para diabetes.
#
# O dataset está disponível em https://www.openml.org/d/37.
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# São 8 atributos mais a classe (onde 1 significa que testou positivo para diabetes):
# - **preg** Number of times pregnant
# - **plas** Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# - **pres** Diastolic blood pressure (mm Hg)
# - **skin** Triceps skin fold thickness (mm)
# - **insu** 2-Hour serum insulin (mu U/mL)
# - **mass** Body mass index (weight in kg/ height in m²)
# - **pedi** Diabetes pedigree function
# - **age** Age (years)
# - **Class** variable (0 or 1)

# %% [markdown]
# ### Exercício 1.1 - Faça análise exploratória dos dados
#
# Realizar leitura da tabela
#
# Exibir dados da tabela
#
# Exibir graficos de histograma de todos as características (features, colunas) da tabela. Obs. Mostrar apenas das features e não da coluna dos rótulos.

# %%
# Para trabalhar com dados em tabelas
import pandas as pd

# Para trabalhar com gráficos
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
dados = pd.read_csv('diabetes.csv', sep=',')

# %%
# Mostrar primeiras linhas dos dados da tabela

# %%
# Mostrar histograma das features (não usar coluna de rótulos)
# Esperado a exibição de 8 histogramas

# %% [markdown]
# ### Exercício 1.2 - Com base na análise dos histogramas, tem alguma feature que tem comportamento difenrete das demais?

# %%
# Resposta:

# %% [markdown]
# ### Exercício 1.3 - Realize separação de dados em treino e teste
#
# Separe nos dois conjuntos.
#
# Vai ser necessário separar a coluna de rótulos Y, aqui denominada de "Outcome"
#
# Exiba as primeiras linhas dos conjuntos resultantes x_train e y_train.

# %%
from sklearn.model_selection import train_test_split

# %%
# Escolha as colunas preditivas e alvo


# Divida em conjunto de treinamento (x_train, y_train) e conjunto de teste (x_test, y_test) com proporção 20%

# %%
# Exibir primeros dados de x_train

# %% [markdown]
# ### Exercício 1.4 - Crie classificadores para predição se uma determinada mulher tem ou não um diagnostico positivo para diabetes.
#
# Utilize os classificadores abaixo:
#
# - Naive Bayes
# - k-vizinhos mais próximos (KNN)
# - Máquina de Vetor Suporte (SVM)
# - RandomForest
#
#
# Para cada classificador acima você deve treinar (função fit), realizar predições no conjunto de teste e comparar com os rótulos originais. Avaliar os resultados (obter acurácia e f1-score de cada classificador).

# %%
from sklearn.metrics import f1_score, accuracy_score, classification_report

# %%
## Coloque seu código aqui (de maneira organizada, dividindo em diferentes células do notebook para cada classificador)

# %%
# k-vizinhos mais próximos (KNN)

# %%
# Naive Bayes Gaussiano

# %%
# RandomForest

# %%
# Máquina de Vetor Suporte

# %% [markdown]
# ### Na célula abaixo, liste os seus resultados obtidos:

# %%
# Resposta:
#Liste os resultados de cada classificadores com suas respectivas acurácias e f1-score.

# Naive Bayes,                     Acurácia =         , F1-score:
# k-vizinhos mais próximos (KNN) , Acurácia =         , F1-score:
# Máquina de Vetor Suporte (SVM),  Acurácia =         , F1-score:
# RandomForest,                    Acurácia =         , F1-score:

# %% [markdown]
# ### Exercício1.5 - Qual foi o melhor Classificador (em acurácia como métrica principal e f1-score (para classe 0) que você conseguiur criar?
#
# Por qual razão você acha que esse classificador em especial funcionou melhor nos dados deste problema?

# %%
# Resposta:

# %% [markdown]
# ### Exercício 1.6 - O que é explicabilidade? Cite um exemplo de algoritmo classificador com alta explicabilidade.

# %%
# Resposta

# %% [markdown]
# ### Exercício 1.7 - Descreva sucintamente os 6 passos da Metodologia de trabalho em ML

# %%
# Resposta
