# %% [markdown]
# # IA & Chatbots: Avaliação Aprendizado Supervisionado: Regressão e Não Supervisionado: Agrupamentos
#
# FIAP - 17/05/2023
#
# Observações gerais:
#
# 1.	Para os gráficos pode-se usar as bibliotecas matplotlib ou seaborn.
#
# 2.	Liberada consulta aos apontamentos de aula.
#
# 3.	Escreve as respostas nas células correspondentes
#
# 4.	A prova deve ser feita em duplas.
#
# 5.	Deve ser entregue um notebook por turma. Salvar com nome: CP2_nome1_nome2.ipynb
#
# 6.	A prova deve ser carregada na tarefa do Teams.
#
# Turma -
#
# Insira os nomes e RM na célula abaixo:
#
# --------------------------

# %%
# Nomes e RM

# %% [markdown]
# ### Bibliotecas utilizadas

# %%
import pandas as pd

# Plot dos gráficos
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import colors
import seaborn as sns
import scipy.cluster.hierarchy as sch   # Dendograma


# Algoritmos de Agrupamento
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.mixture import GaussianMixture

# Avaliacao de desemepnho
from sklearn.metrics import adjusted_rand_score, silhouette_score

# %% [markdown]
# ### Diabetes Dataset
#
# Considere o **dataset** diabetes disponível no SkLearn:
#
#
#
# ![image.png](attachment:image.png)

# %%
from sklearn.datasets import load_diabetes
dia = load_diabetes()

# %%
data = pd.DataFrame(dia.data, columns=dia.feature_names)

# %%
target = pd.DataFrame(dia.target)

# %% [markdown]
# ### 1) Exiba uma amostra dos dados e o alvo lidos deste dataset

# %%
# Resposta:

# %%
# Resposta:

# %% [markdown]
# ### 2) Crie o mapa de correlação das features

# %%
# Resposta

# %% [markdown]
# ### 3) Responda:
# (a)Qual as características mais relacionadas?
#
# (b)Quais as características mais inversamente relacionadas?
#
# (c)O que significa inversamente relaciondas?

# %%
# Resposta

# %% [markdown]
# ### 4) Realize a separação dos dados em treino e teste. Exiba o tamanho desses conjuntos criados.

# %%
# Resposta:

# %% [markdown]
# ### 5)Treine o algoritmo de Regressão Linear com esses dados, excute predição e obtenha a métrica R2

# %%
from sklearn.linear_model import LinearRegression

# %%
# Resposta:

# %% [markdown]
# ### 6)Considerando o resultado da métrica R2, podemos dizer que o resultado foi bom? Caso negativo, o que seria recomendado fazer?

# %%
# Resposta:

# %% [markdown]
# ### 7) O que significa aprendizado não supervisionado?

# %%
# Resposta:

# %% [markdown]
# ### 8) O que é um centróide, que aparece no algoritmo K-means?

# %%
# Resposta:

# %% [markdown]
# ### 9) Cite 2 métricas usadas em aprendizado não supervisionado

# %%
# Resposta:

# %% [markdown]
# ### Considere as seguintes figuras:
#
# (a)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# (b)
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 10) Qual delas representa uma segmentção realizada pelo algoritmo K-means? Porque?

# %%
# Resposta:
